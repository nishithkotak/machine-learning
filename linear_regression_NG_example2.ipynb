# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive #toimport google drive data

# %%
drive.mount('/content/drive') #to mount the drive data into colab clound and enterr the activation code
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/"My Drive"
# Out:
# /content/drive/My Drive

# %%
#this changes the directory tothe drive

# %%
ls
# Out:
#  121.pdf
#  123.JPG
#  abc.txt
# 'Admit card_ISRO.pdf'
#  A.gform
#  Algorithms.zip
# 'ansi c_balaguruswamy.pdf'
#  arm_inst.pdf
# 'Autocad EDW'/
# 'Autocad Exam Group 3'/
# 'Chimp1_small_0 (1).jpg'
#  Chimp1_small_0.jpg
#  Classroom/
#  code.gdoc
# 'Colab Notebooks'/
# 'Common Papers'/
#  Convocation/
# 'CPS_2017_Lecture Recording (1).xlsx.gsheet'
# 'CPS_2017_Lecture Recording (2).xlsx.gsheet'
# 'CPS_2017_Lecture Recording (3).xlsx.gsheet'
# 'CPS_2017_Lecture Recording (4).xlsx.gsheet'
# 'CPS_2017_Lecture Recording (5).xlsx.gsheet'
# 'CPS_2017_Lecture Recording (6).xlsx.gsheet'
# 'CPS_2017_Lecture Recording (7).xlsx.gsheet'
# 'CPS_2017_Lecture Recording.xlsx.gsheet'
# 'cryptography 4th edition.pdf'
# 'dda details'/
# 'Digital Electronics Project Groups.gform'
# 'Douglas B. West-Introduction to Graph Theory (2nd Edition)(With Solution Manual)%20 -Prentice Hall (2000).pdf'
#  download
#  download.gdoc
#  Ebooks/
# 'GCam_6.1.021_V1.4.032219.apk (Unzipped Files)'/
#  housing/
# 'IEEE International MYOSA Students contest-SENSORS 2018.gdoc'
# 'IEEE International MYOSA Students contest-SENSORS 2018.pdf'
# 'IoT Components Not received.gsheet'
# 'IoT Course Project Groups.gform'
# 'IoT Project List.gsheet'
# 'Lab 2_submission.zip'
# 'Lab Viva - EDW.pdf'
# 'Laptop key'/
#  let-us-c-solutions.pdf
# 'Let Us C  Yashwant Kanetkar - 5th Edition.pdf'
# 'LG Soft Papers.gform'
#  MPU6050/
# 'MTech 2k15-17 batch Farewell.mp4'
# 'NG Machine Learning'/
# 'Nishith Kotak_201511056_Verse.pdf'
# 'Nishith Kotak_MU.pdf'
# 'Nishith_tencon paper.pdf'
# 'NISHIT KOTAK AHME,  3 pax from 20,05,19 to 27,05,19 for 7nights,8days.gdoc'
# 'NOV 08.rar'
# 'Offer Letters'/
# 'Open Silicon Registrations.gform'
# 'Open Silicon Registrations (Responses).gsheet'
# 'Personal documents'/
# 'PILL DEPENSER BOTTOM_with Name and usb.3dm'
# 'PILL DEPENSER BOTTOM with name and usb.stl'
#  Project/
#  Rampage.mp4
# 'R basics_Quiz 1.gform'
# 'R basics_Quiz 1 (Responses).gsheet'
# 'Resume_Nishith Kotak_Aspiring Minds.pdf'
#  Sir/
# 'Slot for Lab Viva.gform'
# 'Smart City'/
#  Smart_City_LAB/
# 'Spicejet Flight Notification (1).pdf'
# 'Spicejet Flight Notification (2).pdf'
# 'Spicejet Flight Notification.pdf'
# 'Sprinklr Internship Registration (Responses).xlsx'
#  Sprinklr_Registration.xlsx
# 'Stage 2.rar'
#  TA_IT477.gsheet
#  TASM.zip
#  TechSmith/
#  Thesis/
# 'To-do list.gsheet'
# 'Untitled document.gdoc'
# 'Untitled form (1).gform'
# 'Untitled form (2).gform'
# 'Untitled form (3).gform'
# 'Untitled form (4).gform'
# 'Untitled form (5).gform'
# 'Untitled form (6).gform'
# 'Untitled form.gform'
# 'Untitled form (Responses) (1).gsheet'
# 'Untitled form (Responses).gsheet'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'WATER MONITORIN-WPS Office.doc'
# 'WATER MONITORIN-WPS Office.gdoc'

# %%
columnname=['x','y']
dataset=pd.read_csv("NG Machine Learning/ex1data1.txt",names=columnname)
print(dataset)
dataset.shape
# Out:
#           x         y
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]
# (97, 2)

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.describe()
# Out:
#                x          y
# count  97.000000  97.000000
# mean    8.159800   5.839135
# std     3.869884   5.510262
# min     5.026900  -2.680700
# 25%     5.707700   1.986900
# 50%     6.589400   4.562300
# 75%     8.578100   7.046700
# max    22.203000  24.147000

# %%
x_value = dataset.iloc[0:dataset.shape[0],0:1]
x_value
# Out:
#           x
# 0    6.1101
# 1    5.5277
# 2    8.5186
# 3    7.0032
# 4    5.8598
# ..      ...
# 92   5.8707
# 93   5.3054
# 94   8.2934
# 95  13.3940
# 96   5.4369
#
# [97 rows x 1 columns]

# %%
y_value = dataset.iloc[0:dataset.shape[0],1:2]
y_value
# Out:
#            y
# 0   17.59200
# 1    9.13020
# 2   13.66200
# 3   11.85400
# 4    6.82330
# ..       ...
# 92   7.20290
# 93   1.98690
# 94   0.14454
# 95   9.05510
# 96   0.61705
#
# [97 rows x 1 columns]

# %%
print("Mean of x values is %f and median is %f\n" % (np.mean(x_value), np.median(x_value)))
print("Mean of y values is %f and median is %f\n" % (np.mean(y_value), np.median(y_value)))
# Out:
# Mean of x values is 8.159800 and median is 6.589400
#
# Mean of y values is 5.839135 and median is 4.562300

# %%
import matplotlib.pyplot as plt
plt.scatter(x_value,y_value)
plt.xticks(np.arange(5,30,step=5))
plt.yticks(np.arange(-5,30,step=5))
plt.xlabel("Population of City (10,000s)")
plt.ylabel("Profit ($10,000")
plt.title("Profit Vs Population")
# Out:
# Text(0.5, 1.0, 'Profit Vs Population')

# %%
import seaborn as sns       #boxplot to see outliers data
sns.set(style="whitegrid")
ax = sns.boxplot(x_value)

# %%
sns.set(style="whitegrid")
ay = sns.boxplot(y_value)

# %%
#define hypothesis
def hypothesis(theta_array, x):
    # Returns value of hypothesis at the point corresponding to the 'x' entry
    # H(x) = theta_0 + theta_1*x
    return theta_array[0] + theta_array[1]*x

# %%
#define cost function
def cost_function(theta_array, x_value, y_value, m):
    # This function returns our cost function value at particular theta values
    total_error = 0
    for i in range(m):
        total_error += (theta_array[0] + theta_array[1]*x_value[i] - y_value[i])**2
    return total_error/(2*m)

# %%
#initialize regularization parameters
# initializing values of thetas
    theta_0 = 0  # bias
    theta_1 = 0  # weight
    
    # defining a learning rate
    alpha = 0.005

    # Setting the number of iterations
    iters = 500

# %%
#minimizing cost function error
def training(x_train, y_train, alpha, iters):
    # This is the function which takes care of the Regression

    # Finding size of the training data
    m = x_train.size
    print(m)
    # initializing values of thetas
    theta_0 = 0     # bias
    theta_1 = 0     # weight

    # creating a weight matrix which contains both theta_0 and theta_1
    theta_array = [theta_0, theta_1]

    # creating an array that stores the values of the cost function during each iteration
    cost_function_values = []

    for i in range(iters):
        # changing the values of theta 0 and theta 1 according to the gradient descent method
        theta_array = improvise_thetas(theta_array, x_train, y_train, alpha, m)

        # storing values of the cost function after every improvisation step (gradient descent step)
        cost_function_values.append(cost_function(theta_array, x_train, y_train, m))

        # print values every 10 iterations
        if i % 10 == 0:
            print('value of theta_0 at iteration %d is: ' % i, theta_array[0])
            print('value of theta_1 at iteration %d is: ' % i, theta_array[1], '\n')
            ynew=x_train*theta_array[1]+theta_array[0]
            plt.plot(x_train,ynew,'r')
            plt.scatter(x_train,y_train)
            plt.show()

    # Plot our cost function's progress over our training period to check if the model has learnt
    x = np.arange(0, len(cost_function_values), step=1)
    plt.plot(x, cost_function_values, "-b", label="Cost Function Curve")
    plt.title("Learning Curve")
    plt.xlabel("Number Of Iterations")
    plt.ylabel("Cost Function Value")
    plt.legend()
    plt.show()
    print("Cost function values: ",cost_function_values)
    # By returning our theta_array and saving it we are basically saving our trained model
    return theta_array

# %%
#update the values of theta by gradient descent
def improvise_thetas(theta_array, X, Y, alpha, m):
    ''' This function updates the values of theta_0 and theta_1 and returns an array containing
            the updated theta values. This is where gradient descent takes place '''

    # initializing summations to zero
    summation_0 = 0
    summation_1 = 0

    for i in range(m):        # finding the value of summations and finally the value of
        summation_0 += (theta_array[0] + theta_array[1]*X[i]) - Y[i]

        summation_1 += X[i]*((theta_array[0] + theta_array[1]*X[i])-Y[i])

    new_theta_0 = theta_array[0] - alpha * (summation_0) / m

    new_theta_1 = theta_array[1] - alpha * (summation_1) / m

    updated_theta_array = [new_theta_0, new_theta_1]
    print(updated_theta_array)
    return updated_theta_array

# %%
columnname=['x','y']
raw_training_data = pd.read_csv("NG Machine Learning/ex1data1.txt",names=columnname)

cleaned_training_data = raw_training_data.dropna()  # Cleaning the data by removing the rows with "NaN" values in them. dropna() does the job
x_train_new = cleaned_training_data.as_matrix(columns=['x'])
y_train_new = cleaned_training_data.as_matrix(columns=['y'])

# reshaping the data from (699,1) to (699)
x_train = x_train_new.reshape(x_train_new.size)
y_train = y_train_new.reshape(y_train_new.size)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
cleaned_training_data
# Out:
#      6.1101    17.592
# 0    5.5277   9.13020
# 1    8.5186  13.66200
# 2    7.0032  11.85400
# 3    5.8598   6.82330
# 4    8.3829  11.88600
# ..      ...       ...
# 91   5.8707   7.20290
# 92   5.3054   1.98690
# 93   8.2934   0.14454
# 94  13.3940   9.05510
# 95   5.4369   0.61705
#
# [96 rows x 2 columns]

# %%
    # training time!
theta_array = training(x_train, y_train, alpha, iters)

print("\n*** The final value of theta_0 is ",theta_array[0]," and theta_1 is ",theta_array[1]," ***\n")
# Out:
# 97
# [0.02919567525773195, 0.32664424872778364]
# value of theta_0 at iteration 0 is:  0.02919567525773195
# value of theta_1 at iteration 0 is:  0.32664424872778364
# [0.04491861343533039, 0.5191466943677676]
# [0.052709029642375144, 0.6326553694631222]
# [0.055829453333169306, 0.6996459348812943]
# [0.05620112682701349, 0.7392427093487134]
# [0.054955433151892226, 0.7627076520858378]
# [0.05275862174641463, 0.7766727235947343]
# [0.05000303344547295, 0.7850433633990819]
# [0.046919709352658406, 0.7901194130304335]
# [0.04364470413139842, 0.7932552069316855]
# [0.04025813668086755, 0.7952482878337632]
# value of theta_0 at iteration 10 is:  0.04025813668086755
# value of theta_1 at iteration 10 is:  0.7952482878337632
# [0.03680718635986546, 0.7965683140822928]
# [0.03331963503955463, 0.7974918589466743]
# [0.02981184176892345, 0.7981817914507046]
# [0.0262934389084135, 0.7987340222818375]
# [0.0227700975965267, 0.7992050315962658]
# [0.019245156282179977, 0.7996280796363758]
# [0.01572057973741654, 0.8000227528648294]
# [0.012197523802329243, 0.8004005855071206]
# [0.008676667952944543, 0.8007683699744604]
# [0.005158411144323768, 0.8011301063108485]
# value of theta_0 at iteration 20 is:  0.005158411144323768
# value of theta_1 at iteration 20 is:  0.8011301063108485
# [0.0016429871389578008, 0.8014881501865515]
# [-0.0018694675784661431, 0.8018438889303219]
# [-0.0053788738073100575, 0.802198139632321]
# [-0.008885186079400613, 0.8025513835795997]
# [-0.012388378789935733, 0.8029039043108348]
# [-0.015888438030231843, 0.8032558689142218]
# [-0.01938535677818006, 0.8036073759023061]
# [-0.02287913206599539, 0.8039584834045901]
# [-0.026369763312357325, 0.80430922576964]
# [-0.029857251340239123, 0.8046596233417613]
# value of theta_0 at iteration 30 is:  -0.029857251340239123
# value of theta_1 at iteration 30 is:  0.8046596233417613
# [-0.03334159779852649, 0.8050096882183024]
# [-0.03682280482142042, 0.8053594276400253]
# [-0.040300874827866755, 0.8057088459876326]
# [-0.04377581040344489, 0.8060579459574848]
# [-0.047247614230815124, 0.8064067292539598]
# [-0.050716289048761395, 0.8067551969971701]
# [-0.05418183762807317, 0.8071033499630597]
# [-0.05764426275734372, 0.8074511887247935]
# [-0.061103567234607886, 0.807798713736019]
# [-0.06455975386241873, 0.8081459253798973]
# value of theta_0 at iteration 40 is:  -0.06455975386241873
# value of theta_1 at iteration 40 is:  0.8081459253798973
# [-0.0680128254449491, 0.8084928239979765]
# [-0.07146278478628584, 0.8088394099071955]
# [-0.07490963468942613, 0.8091856834098967]
# [-0.07835337795568742, 0.8095316447997227]
# [-0.08179401738436091, 0.8098772943650887]
# [-0.0852315557725084, 0.8102226323912276]
# [-0.0886659959148436, 0.8105676591613941]
# [-0.09209734060366315, 0.8109123749575741]
# [-0.09552559262880693, 0.8112567800609027]
# [-0.09895075477763571, 0.8116008747519102]
# value of theta_0 at iteration 50 is:  -0.09895075477763571
# value of theta_1 at iteration 50 is:  0.8116008747519102
# [-0.10237282983501876, 0.8119446593106671]
# [-0.10579182058332762, 0.8122881340168694]
# [-0.10920772980243328, 0.8126312991498893]
# [-0.11262056026970549, 0.8129741549888051]
# [-0.11603031476001326, 0.8133167018124186]
# [-0.1194369960457261, 0.8136589398992656]
# [-0.12284060689671564, 0.8140008695276223]
# [-0.12624115008035755, 0.8143424909755089]
# [-0.1296386283615336, 0.8146838045206922]
# [-0.13303304450263367, 0.8150248104406868]
# value of theta_0 at iteration 60 is:  -0.13303304450263367
# value of theta_1 at iteration 60 is:  0.8150248104406868
# [-0.13642440126355812, 0.8153655090127558]
# [-0.1398127014017198, 0.8157059005139126]
# [-0.14319794767204636, 0.8160459852209198]
# [-0.14658014282698248, 0.8163857634102907]
# [-0.14995928961649205, 0.8167252353582891]
# [-0.15333539078806047, 0.81706440134093]
# [-0.15670844908669682, 0.8174032616339793]
# [-0.1600784672549361, 0.8177418165129543]
# [-0.16344544803284147, 0.8180800662531243]
# [-0.16680939415800652, 0.8184180111295102]
# value of theta_0 at iteration 70 is:  -0.16680939415800652
# value of theta_1 at iteration 70 is:  0.8184180111295102
# [-0.1701703083655574, 0.818755651416885]
# [-0.17352819338815514, 0.8190929873897743]
# [-0.17688305195599782, 0.8194300193224561]
# [-0.18023488679682276, 0.8197667474889611]
# [-0.18358370063590881, 0.8201031721630732]
# [-0.18692949619607854, 0.8204392936183293]
# [-0.1902722761977004, 0.8207751121280201]
# [-0.19361204335869103, 0.8211106279651899]
# [-0.1969488003945174, 0.8214458414026365]
# [-0.20028255001819903, 0.8217807527129124]
# value of theta_0 at iteration 80 is:  -0.20028255001819903
# value of theta_1 at iteration 80 is:  0.8217807527129124
# [-0.2036132949403102, 0.822115362168324]
# [-0.20694103786898213, 0.8224496700409326]
# [-0.21026578150990527, 0.8227836766025541]
# [-0.2135875285663314, 0.8231173821247595]
# [-0.21690628173907583, 0.823450786878875]
# [-0.2202220437265197, 0.8237838911359822]
# [-0.2235348172246121, 0.8241166951669183]
# [-0.2268446049268722, 0.8244491992422768]
# [-0.23015140952439153, 0.8247814036324068]
# [-0.23345523370583618, 0.8251133086074142]
# value of theta_0 at iteration 90 is:  -0.23345523370583618
# value of theta_1 at iteration 90 is:  0.8251133086074142
# [-0.23675608015744892, 0.825444914437161]
# [-0.24005395156305145, 0.8257762213912663]
# [-0.2433488506040465, 0.8261072297391061]
# [-0.2466407799594201, 0.8264379397498136]
# [-0.2499297423057437, 0.8267683516922794]
# [-0.2532157403171763, 0.8270984658351517]
# [-0.25649877666546683, 0.8274282824468369]
# [-0.25977885401995604, 0.827757801795499]
# [-0.2630559750475789, 0.8280870241490607]
# [-0.26633014241286657, 0.8284159497752029]
# value of theta_0 at iteration 100 is:  -0.26633014241286657
# value of theta_1 at iteration 100 is:  0.8284159497752029
# [-0.2696013587779488, 0.8287445789413656]
# [-0.27286962680255583, 0.8290729119147473]
# [-0.27613494914402087, 0.8294009489623062]
# [-0.27939732845728193, 0.8297286903507596]
# [-0.2826567673948842, 0.8300561363465843]
# [-0.28591326860698213, 0.8303832872160171]
# [-0.2891668347413415, 0.8307101432250548]
# [-0.2924174684433419, 0.8310367046394544]
# [-0.29566517235597833, 0.8313629717247336]
# [-0.2989099491198639, 0.8316889447461704]
# value of theta_0 at iteration 110 is:  -0.2989099491198639
# value of theta_1 at iteration 110 is:  0.8316889447461704
# [-0.3021518013732316, 0.8320146239688041]
# [-0.3053907317519367, 0.8323400096574349]
# [-0.30862674288945874, 0.8326651020766245]
# [-0.3118598374169037, 0.8329899014906958]
# [-0.3150900179630061, 0.8333144081637339]
# [-0.3183172871541313, 0.8336386223595855]
# [-0.32154164761427745, 0.8339625443418598]
# [-0.3247631019650776, 0.8342861743739283]
# [-0.32798165282580216, 0.834609512718925]
# [-0.33119730281336063, 0.834932559639747]
# value of theta_0 at iteration 120 is:  -0.33119730281336063
# value of theta_1 at iteration 120 is:  0.834932559639747
# [-0.3344100545423039, 0.8352553153990543]
# [-0.33761991062482644, 0.83557778025927]
# [-0.3408268736707683, 0.8358999544825809]
# [-0.3440309462876173, 0.8362218383309374]
# [-0.3472321310805112, 0.836543432066054]
# [-0.3504304306522396, 0.836864735949409]
# [-0.3536258476032464, 0.8371857502422453]
# [-0.35681838453163156, 0.8375064752055702]
# [-0.3600080440331535, 0.8378269111001557]
# [-0.36319482870123104, 0.838147058186539]
# value of theta_0 at iteration 130 is:  -0.36319482870123104
# value of theta_1 at iteration 130 is:  0.838147058186539
# [-0.3663787411269455, 0.8384669167250222]
# [-0.369559783899043, 0.8387864869756729]
# [-0.3727379596039363, 0.8391057691983245]
# [-0.3759132708257071, 0.8394247636525758]
# [-0.37908572014610803, 0.839743470597792]
# [-0.3822553101445648, 0.8400618902931044]
# [-0.3854220433981784, 0.8403800229974107]
# [-0.3885859224817269, 0.8406978689693753]
# [-0.39174694996766785, 0.8410154284674294]
# [-0.3949051284261402, 0.8413327017497714]
# value of theta_0 at iteration 140 is:  -0.3949051284261402
# value of theta_1 at iteration 140 is:  0.8413327017497714
# [-0.39806046042496646, 0.8416496890743669]
# [-0.4012129485296548, 0.8419663906989491]
# [-0.40436259530340096, 0.8422828068810188]
# [-0.4075094033070907, 0.8425989378778447]
# [-0.41065337509930144, 0.8429147839464636]
# [-0.41379451323630473, 0.8432303453436808]
# [-0.41693282027206807, 0.84354562232607]
# [-0.4200682987582571, 0.8438606151499737]
# [-0.4232009512442376, 0.8441753240715033]
# [-0.4263307802770777, 0.8444897493465395]
# value of theta_0 at iteration 150 is:  -0.4263307802770777
# value of theta_1 at iteration 150 is:  0.8444897493465395
# [-0.42945778840154986, 0.8448038912307323]
# [-0.4325819781601328, 0.8451177499795012]
# [-0.4357033520930138, 0.8454313258480356]
# [-0.4388219127380908, 0.8457446190912948]
# [-0.4419376626309741, 0.8460576299640085]
# [-0.4450506043049889, 0.8463703587206766]
# [-0.44816074029117686, 0.8466828056155696]
# [-0.45126807311829864, 0.8469949709027291]
# [-0.45437260531283563, 0.8473068548359676]
# [-0.4574743393989921, 0.8476184576688686]
# value of theta_0 at iteration 160 is:  -0.4574743393989921
# value of theta_1 at iteration 160 is:  0.8476184576688686
# [-0.4605732778986974, 0.8479297796547873]
# [-0.4636694233316076, 0.8482408210468507]
# [-0.4667627782151081, 0.8485515820979572]
# [-0.46985334506431514, 0.8488620630607777]
# [-0.4729411263920783, 0.8491722641877552]
# [-0.4760261247089822, 0.8494821857311049]
# [-0.47910834252334866, 0.8497918279428152]
# [-0.4821877823412389, 0.850101191074647]
# [-0.48526444666645524, 0.8504102753781345]
# [-0.4883383380005435, 0.850719081104585]
# value of theta_0 at iteration 170 is:  -0.4883383380005435
# value of theta_1 at iteration 170 is:  0.850719081104585
# [-0.4914094588427948, 0.8510276085050795]
# [-0.4944778116902476, 0.8513358578304725]
# [-0.4975433990376899, 0.8516438293313926]
# [-0.500606223377661, 0.8519515232582424]
# [-0.5036662872004538, 0.8522589398611988]
# [-0.5067235929941166, 0.8525660793902132]
# [-0.5097781432444554, 0.8528729420950119]
# [-0.5128299404350355, 0.8531795282250958]
# [-0.515878987047184, 0.8534858380297413]
# [-0.5189252855599916, 0.8537918717579999]
# value of theta_0 at iteration 180 is:  -0.5189252855599916
# value of theta_1 at iteration 180 is:  0.8537918717579999
# [-0.5219688384503144, 0.8540976296586985]
# [-0.5250096481927761, 0.8544031119804402]
# [-0.5280477172597702, 0.8547083189716034]
# [-0.5310830481214618, 0.8550132508803432]
# [-0.5341156432457896, 0.8553179079545908]
# [-0.537145505098468, 0.855622290442054]
# [-0.540172636142989, 0.855926398590217]
# [-0.5431970388406244, 0.8562302326463416]
# [-0.5462187156504275, 0.8565337928574661]
# [-0.5492376690292351, 0.8568370794704067]
# value of theta_0 at iteration 190 is:  -0.5492376690292351
# value of theta_1 at iteration 190 is:  0.8568370794704067
# [-0.5522539014316701, 0.8571400927317566]
# [-0.5552674153101427, 0.8574428328878873]
# [-0.5582782131148529, 0.8577453001849478]
# [-0.5612862972937924, 0.8580474948688653]
# [-0.5642916702927463, 0.8583494171853456]
# [-0.5672943345552955, 0.858651067379873]
# [-0.5702942925228185, 0.8589524456977102]
# [-0.5732915466344933, 0.8592535523838992]
# [-0.5762860993272996, 0.8595543876832611]
# [-0.5792779530360205, 0.8598549518403962]
# value of theta_0 at iteration 200 is:  -0.5792779530360205
# value of theta_1 at iteration 200 is:  0.8598549518403962
# [-0.5822671101932447, 0.8601552450996844]
# [-0.5852535732293686, 0.8604552677052856]
# [-0.5882373445725977, 0.8607550199011391]
# [-0.5912184266489493, 0.8610545019309648]
# [-0.594196821882254, 0.8613537140382628]
# [-0.5971725326941578, 0.8616526564663135]
# [-0.6001455615041242, 0.8619513294581785]
# [-0.6031159107294359, 0.8622497332567]
# [-0.6060835827851969, 0.8625478681045012]
# [-0.6090485800843345, 0.8628457342439871]
# value of theta_0 at iteration 210 is:  -0.6090485800843345
# value of theta_1 at iteration 210 is:  0.8628457342439871
# [-0.6120109050376012, 0.8631433319173438]
# [-0.614970560053577, 0.8634406613665393]
# [-0.6179275475386705, 0.8637377228333235]
# [-0.620881869897122, 0.8640345165592284]
# [-0.6238335295310045, 0.8643310427855682]
# [-0.6267825288402259, 0.8646273017534397]
# [-0.6297288702225314, 0.8649232937037225]
# [-0.632672556073505, 0.8652190188770789]
# [-0.6356135887865715, 0.8655144775139544]
# [-0.6385519707529985, 0.8658096698545777]
# value of theta_0 at iteration 220 is:  -0.6385519707529985
# value of theta_1 at iteration 220 is:  0.8658096698545777
# [-0.6414877043618985, 0.8661045961389613]
# [-0.6444207920002305, 0.866399256606901]
# [-0.6473512360528023, 0.8666936514979765]
# [-0.6502790389022722, 0.8669877810515519]
# [-0.6532042029291512, 0.8672816455067752]
# [-0.6561267305118044, 0.8675752451025789]
# [-0.6590466240264535, 0.8678685800776803]
# [-0.6619638858471786, 0.8681616506705816]
# [-0.6648785183459198, 0.8684544571195698]
# [-0.6677905238924796, 0.8687469996627173]
# value of theta_0 at iteration 230 is:  -0.6677905238924796
# value of theta_1 at iteration 230 is:  0.8687469996627173
# [-0.6706999048545245, 0.869039278537882]
# [-0.6736066635975869, 0.869331293982707]
# [-0.6765108024850675, 0.8696230462346218]
# [-0.6794123238782365, 0.8699145355308415]
# [-0.6823112301362362, 0.8702057621083676]
# [-0.6852075236160823, 0.8704967262039879]
# [-0.6881012066726664, 0.8707874280542767]
# [-0.6909922816587575, 0.871077867895595]
# [-0.6938807509250041, 0.8713680459640913]
# [-0.6967666168199361, 0.8716579624957007]
# value of theta_0 at iteration 240 is:  -0.6967666168199361
# value of theta_1 at iteration 240 is:  0.8716579624957007
# [-0.6996498816899666, 0.871947617726146]
# [-0.7025305478793938, 0.8722370118909373]
# [-0.7054086177304033, 0.8725261452253724]
# [-0.7082840935830693, 0.8728150179645373]
# [-0.7111569777753571, 0.8731036303433061]
# [-0.7140272726431249, 0.8733919825963408]
# [-0.7168949805201255, 0.8736800749580923]
# [-0.719760103738008, 0.8739679076628001]
# [-0.7226226446263206, 0.8742554809444925]
# [-0.7254826055125114, 0.874542795036987]
# value of theta_0 at iteration 250 is:  -0.7254826055125114
# value of theta_1 at iteration 250 is:  0.874542795036987
# [-0.728339988721931, 0.8748298501738901]
# [-0.7311947965778339, 0.8751166465885982]
# [-0.7340470314013811, 0.875403184514297]
# [-0.7368966955116409, 0.875689464183962]
# [-0.7397437912255922, 0.8759754858303588]
# [-0.7425883208581251, 0.8762612496860434]
# [-0.7454302867220434, 0.8765467559833618]
# [-0.7482696911280664, 0.876832004954451]
# [-0.7511065363848307, 0.8771169968312386]
# [-0.7539408247988924, 0.877401731845443]
# value of theta_0 at iteration 260 is:  -0.7539408247988924
# value of theta_1 at iteration 260 is:  0.877401731845443
# [-0.7567725586747281, 0.8776862102285741]
# [-0.7596017403147381, 0.8779704322119328]
# [-0.7624283720192472, 0.8782543980266118]
# [-0.7652524560865067, 0.8785381079034953]
# [-0.7680739948126969, 0.8788215620732595]
# [-0.7708929904919284, 0.8791047607663727]
# [-0.773709445416244, 0.8793877042130955]
# [-0.7765233618756209, 0.879670392643481]
# [-0.7793347421579722, 0.8799528262873748]
# [-0.7821435885491489, 0.8802350053744155]
# value of theta_0 at iteration 270 is:  -0.7821435885491489
# value of theta_1 at iteration 270 is:  0.8802350053744155
# [-0.784949903332942, 0.8805169301340345]
# [-0.7877536887910839, 0.8807986007954568]
# [-0.7905549472032504, 0.8810800175877005]
# [-0.7933536808470627, 0.8813611807395773]
# [-0.7961498919980894, 0.8816420904796927]
# [-0.7989435829298479, 0.8819227470364462]
# [-0.8017347559138067, 0.8822031506380317]
# [-0.8045234132193868, 0.8824833015124368]
# [-0.8073095571139638, 0.8827631998874441]
# [-0.8100931898628698, 0.883042845990631]
# value of theta_0 at iteration 280 is:  -0.8100931898628698
# value of theta_1 at iteration 280 is:  0.883042845990631
# [-0.8128743137293952, 0.8833222400493692]
# [-0.8156529309747905, 0.8836013822908261]
# [-0.818429043858268, 0.8838802729419639]
# [-0.8212026546370038, 0.8841589122295406]
# [-0.8239737655661399, 0.8844373003801096]
# [-0.8267423788987853, 0.8847154376200201]
# [-0.8295084968860187, 0.8849933241754174]
# [-0.8322721217768895, 0.885270960272243]
# [-0.8350332558184204, 0.8855483461362345]
# [-0.8377919012556085, 0.8858254819929263]
# value of theta_0 at iteration 290 is:  -0.8377919012556085
# value of theta_1 at iteration 290 is:  0.8858254819929263
# [-0.8405480603314279, 0.8861023680676496]
# [-0.8433017352868308, 0.8863790045855323]
# [-0.8460529283607499, 0.8866553917714993]
# [-0.8488016417900995, 0.8869315298502731]
# [-0.8515478778097784, 0.8872074190463735]
# [-0.8542916386526705, 0.8874830595841179]
# [-0.8570329265496477, 0.8877584516876215]
# [-0.8597717437295708, 0.8880335955807975]
# [-0.8625080924192919, 0.8883084914873576]
# [-0.8652419748436562, 0.8885831396308114]
# value of theta_0 at iteration 300 is:  -0.8652419748436562
# value of theta_1 at iteration 300 is:  0.8885831396308114
# [-0.8679733932255034, 0.8888575402344673]
# [-0.87070234978567, 0.8891316935214325]
# [-0.8734288467429906, 0.889405599714613]
# [-0.8761528863143002, 0.8896792590367139]
# [-0.8788744707144357, 0.8899526717102394]
# [-0.8815936021562376, 0.8902258379574935]
# [-0.8843102828505522, 0.8904987580005799]
# [-0.8870245150062331, 0.8907714320614015]
# [-0.8897363008301431, 0.8910438603616619]
# [-0.8924456425271559, 0.8913160431228645]
# value of theta_0 at iteration 310 is:  -0.8924456425271559
# value of theta_1 at iteration 310 is:  0.8913160431228645
# [-0.8951525423001578, 0.891587980566313]
# [-0.8978570023500501, 0.891859672913112]
# [-0.9005590248757499, 0.8921311203841664]
# [-0.9032586120741928, 0.8924023232001823]
# [-0.9059557661403341, 0.8926732815816668]
# [-0.908650489267151, 0.8929439957489281]
# [-0.9113427836456438, 0.8932144659220762]
# [-0.9140326514648384, 0.8934846923210222]
# [-0.9167200949117876, 0.8937546751654796]
# [-0.9194051161715732, 0.8940244146749633]
# value of theta_0 at iteration 320 is:  -0.9194051161715732
# value of theta_1 at iteration 320 is:  0.8940244146749633
# [-0.9220877174273072, 0.8942939110687906]
# [-0.9247679008601343, 0.8945631645660813]
# [-0.9274456686492332, 0.8948321753857574]
# [-0.9301210229718185, 0.8951009437465439]
# [-0.9327939660031427, 0.8953694698669683]
# [-0.9354644999164975, 0.8956377539653614]
# [-0.9381326268832159, 0.8959057962598571]
# [-0.9407983490726737, 0.8961735969683929]
# [-0.9434616686522919, 0.8964411563087097]
# [-0.9461225877875374, 0.896708474498352]
# value of theta_0 at iteration 330 is:  -0.9461225877875374
# value of theta_1 at iteration 330 is:  0.896708474498352
# [-0.9487811086419261, 0.8969755517546685]
# [-0.9514372333770232, 0.8972423882948118]
# [-0.9540909641524462, 0.8975089843357391]
# [-0.9567423031258658, 0.8977753400942117]
# [-0.9593912524530083, 0.8980414557867956]
# [-0.9620378142876568, 0.8983073316298619]
# [-0.9646819907816533, 0.8985729678395863]
# [-0.9673237840849004, 0.8988383646319499]
# [-0.9699631963453629, 0.899103522222739]
# [-0.9726002297090697, 0.8993684408275456]
# value of theta_0 at iteration 340 is:  -0.9726002297090697
# value of theta_1 at iteration 340 is:  0.8993684408275456
# [-0.9752348863201155, 0.8996331206617673]
# [-0.9778671683206623, 0.8998975619406073]
# [-0.9804970778509419, 0.9001617648790752]
# [-0.9831246170492566, 0.9004257296919866]
# [-0.9857497880519817, 0.9006894565939637]
# [-0.988372592993567, 0.9009529457994351]
# [-0.9909930340065383, 0.9012161975226362]
# [-0.9936111132214996, 0.901479211977609]
# [-0.9962268327671346, 0.9017419893782032]
# [-0.9988401947702084, 0.9020045299380752]
# value of theta_0 at iteration 350 is:  -0.9988401947702084
# value of theta_1 at iteration 350 is:  0.9020045299380752
# [-1.001451201355569, 0.9022668338706892]
# [-1.0040598546461494, 0.9025289013893167]
# [-1.0066661567629696, 0.9027907327070372]
# [-1.009270109825137, 0.9030523280367382]
# [-1.0118717159498503, 0.9033136875911151]
# [-1.014470977252399, 0.9035748115826716]
# [-1.0170678958461665, 0.9038357002237202]
# [-1.0196624738426312, 0.9040963537263816]
# [-1.0222547133513686, 0.9043567723025857]
# [-1.024844616480053, 0.9046169561640712]
# value of theta_0 at iteration 360 is:  -1.024844616480053
# value of theta_1 at iteration 360 is:  0.9046169561640712
# [-1.0274321853344588, 0.904876905522386]
# [-1.0300174220184624, 0.9051366205888872]
# [-1.0326003286340442, 0.9053961015747416]
# [-1.0351809072812899, 0.9056553486909256]
# [-1.0377591600583926, 0.9059143621482254]
# [-1.040335089061654, 0.9061731421572374]
# [-1.042908696385487, 0.9064316889283679]
# [-1.045479984122416, 0.9066900026718338]
# [-1.0480489543630802, 0.9069480835976623]
# [-1.050615609196234, 0.9072059319156918]
# value of theta_0 at iteration 370 is:  -1.050615609196234
# value of theta_1 at iteration 370 is:  0.9072059319156918
# [-1.0531799507087491, 0.9074635478355708]
# [-1.055741980985617, 0.9077209315667596]
# [-1.0583017021099492, 0.9079780833185291]
# [-1.0608591161629801, 0.9082350032999622]
# [-1.0634142252240684, 0.9084916917199527]
# [-1.0659670313706984, 0.9087481487872066]
# [-1.0685175366784823, 0.9090043747102415]
# [-1.071065743221161, 0.9092603696973875]
# [-1.073611653070607, 0.9095161339567864]
# [-1.076155268296825, 0.9097716676963927]
# value of theta_0 at iteration 380 is:  -1.076155268296825
# value of theta_1 at iteration 380 is:  0.9097716676963927
# [-1.078696590967954, 0.9100269711239733]
# [-1.0812356231502693, 0.9102820444471081]
# [-1.0837723669081836, 0.9105368878731896]
# [-1.0863068243042489, 0.9107915016094238]
# [-1.0888389973991586, 0.9110458858628294]
# [-1.0913688882517485, 0.911300040840239]
# [-1.0938964989189988, 0.9115539667482984]
# [-1.0964218314560357, 0.9118076637934673]
# [-1.0989448879161332, 0.9120611321820196]
# [-1.1014656703507149, 0.9123143721200427]
# value of theta_0 at iteration 390 is:  -1.1014656703507149
# value of theta_1 at iteration 390 is:  0.9123143721200427
# [-1.103984180809355, 0.9125673838134389]
# [-1.1065004213397807, 0.9128201674679245]
# [-1.1090143939878736, 0.9130727232890304]
# [-1.1115261007976713, 0.9133250514821025]
# [-1.1140355438113694, 0.9135771522523013]
# [-1.1165427250693223, 0.9138290258046027]
# [-1.1190476466100456, 0.9140806723437976]
# [-1.121550310470218, 0.9143320920744926]
# [-1.1240507186846822, 0.9145832852011095]
# [-1.1265488732864468, 0.9148342519278864]
# value of theta_0 at iteration 400 is:  -1.1265488732864468
# value of theta_1 at iteration 400 is:  0.9148342519278864
# [-1.1290447763066884, 0.9150849924588766]
# [-1.1315384297747528, 0.9153355069979503]
# [-1.1340298357181564, 0.9155857957487932]
# [-1.1365189961625888, 0.9158358589149079]
# [-1.1390059131319132, 0.9160856966996135]
# [-1.1414905886481692, 0.9163353093060458]
# [-1.1439730247315738, 0.9165846969371574]
# [-1.1464532234005231, 0.9168338597957181]
# [-1.148931186671594, 0.917082798084315]
# [-1.1514069165595462, 0.9173315120053525]
# value of theta_0 at iteration 410 is:  -1.1514069165595462
# value of theta_1 at iteration 410 is:  0.9173315120053525
# [-1.153880415077323, 0.9175800017610526]
# [-1.1563516842360535, 0.9178282675534551]
# [-1.1588207260450547, 0.9180763095844177]
# [-1.161287542511832, 0.9183241280556159]
# [-1.1637521356420821, 0.9185717231685439]
# [-1.1662145074396932, 0.9188190951245138]
# [-1.168674659906748, 0.9190662441246567]
# [-1.171132595043524, 0.9193131703699221]
# [-1.173588314848497, 0.9195598740610786]
# [-1.1760418213183403, 0.9198063553987138]
# value of theta_0 at iteration 420 is:  -1.1760418213183403
# value of theta_1 at iteration 420 is:  0.9198063553987138
# [-1.1784931164479289, 0.9200526145832343]
# [-1.1809422022303386, 0.9202986518148663]
# [-1.1833890806568497, 0.9205444672936555]
# [-1.1858337537169472, 0.9207900612194672]
# [-1.1882762233983235, 0.9210354337919867]
# [-1.190716491686879, 0.9212805852107193]
# [-1.1931545605667249, 0.9215255156749904]
# [-1.1955904320201831, 0.9217702253839458]
# [-1.1980241080277898, 0.9220147145365518]
# [-1.2004555905682956, 0.9222589833315954]
# value of theta_0 at iteration 430 is:  -1.2004555905682956
# value of theta_1 at iteration 430 is:  0.9222589833315954
# [-1.202884881618668, 0.9225030319676844]
# [-1.2053119831540922, 0.9227468606432475]
# [-1.2077368971479736, 0.9229904695565349]
# [-1.210159625571939, 0.9232338589056176]
# [-1.2125801703958374, 0.9234770288883886]
# [-1.2149985335877436, 0.9237199797025621]
# [-1.2174147171139578, 0.9239627115456744]
# [-1.219828722939008, 0.9242052246150837]
# [-1.2222405530256517, 0.9244475191079703]
# [-1.2246502093348777, 0.9246895952213366]
# value of theta_0 at iteration 440 is:  -1.2246502093348777
# value of theta_1 at iteration 440 is:  0.9246895952213366
# [-1.2270576938259066, 0.9249314531520078]
# [-1.229463008456194, 0.9251730930966313]
# [-1.2318661551814305, 0.9254145152516776]
# [-1.2342671359555446, 0.9256557198134401]
# [-1.2366659527307036, 0.925896706978035]
# [-1.239062607457315, 0.9261374769414018]
# [-1.2414571020840288, 0.9263780298993037]
# [-1.2438494385577383, 0.9266183660473274]
# [-1.2462396188235827, 0.926858485580883]
# [-1.2486276448249474, 0.9270983886952047]
# value of theta_0 at iteration 450 is:  -1.2486276448249474
# value of theta_1 at iteration 450 is:  0.9270983886952047
# [-1.2510135185034663, 0.9273380755853506]
# [-1.2533972417990238, 0.9275775464462033]
# [-1.2557788166497554, 0.9278168014724694]
# [-1.2581582449920499, 0.9280558408586802]
# [-1.2605355287605509, 0.9282946647991916]
# [-1.2629106698881585, 0.9285332734881845]
# [-1.2652836703060302, 0.9287716671196645]
# [-1.2676545319435832, 0.9290098458874626]
# [-1.270023256728496, 0.9292478099852349]
# [-1.2723898465867092, 0.9294855596064631]
# value of theta_0 at iteration 460 is:  -1.2723898465867092
# value of theta_1 at iteration 460 is:  0.9294855596064631
# [-1.2747543034424278, 0.9297230949444543]
# [-1.2771166292181224, 0.9299604161923417]
# [-1.2794768258345313, 0.9301975235430843]
# [-1.2818348952106609, 0.930434417189467]
# [-1.2841908392637886, 0.9306710973241011]
# [-1.2865446599094637, 0.9309075641394244]
# [-1.2888963590615088, 0.9311438178277012]
# [-1.2912459386320216, 0.9313798585810223]
# [-1.2935934005313767, 0.9316156865913057]
# [-1.2959387466682266, 0.9318513020502961]
# value of theta_0 at iteration 470 is:  -1.2959387466682266
# value of theta_1 at iteration 470 is:  0.9318513020502961
# [-1.2982819789495035, 0.9320867051495656]
# [-1.300623099280421, 0.9323218960805136]
# [-1.302962109564476, 0.9325568750343669]
# [-1.3052990117034486, 0.93279164220218]
# [-1.307633807597406, 0.9330261977748353]
# [-1.3099664991447026, 0.933260541943043]
# [-1.3122970882419813, 0.9334946748973416]
# [-1.3146255767841761, 0.9337285968280976]
# [-1.3169519666645129, 0.9339623079255062]
# [-1.3192762597745111, 0.9341958083795909]
# value of theta_0 at iteration 480 is:  -1.3192762597745111
# value of theta_1 at iteration 480 is:  0.9341958083795909
# [-1.3215984580039855, 0.9344290983802044]
# [-1.3239185632410475, 0.9346621781170277]
# [-1.326236577372107, 0.9348950477795711]
# [-1.3285525022818732, 0.9351277075571742]
# [-1.330866339853357, 0.9353601576390059]
# [-1.333178091967872, 0.9355923982140645]
# [-1.3354877605050361, 0.935824429471178]
# [-1.3377953473427735, 0.9360562515990043]
# [-1.3401008543573154, 0.9362878647860311]
# [-1.3424042834232022, 0.9365192692205765]
# value of theta_0 at iteration 490 is:  -1.3424042834232022
# value of theta_1 at iteration 490 is:  0.9365192692205765
# [-1.3447056364132846, 0.9367504650907884]
# [-1.3470049151987253, 0.9369814525846455]
# [-1.3493021216490007, 0.9372122318899571]
# [-1.351597257631902, 0.9374428031943629]
# [-1.3538903250135372, 0.9376731666853338]
# [-1.3561813256583326, 0.9379033225501717]
# [-1.3584702614290334, 0.9381332709760094]
# [-1.3607571341867064, 0.9383630121498114]
# [-1.363041945790741, 0.9385925462583735]
# Cost function values:  [14.983962756239949, 9.056203941047666, 6.998880978009592, 6.283756679195572, 6.034085104841375, 5.945826960067565, 5.913547030682458, 5.900682327431493, 5.894553475901442, 5.890763497940391, 5.887787597368801, 5.885096997646217, 5.882508323446061, 5.879957978209339, 5.877423902449826, 5.874898440980178, 5.872378933767395, 5.869864453015334, 5.8673546716452165, 5.864849470905552, 5.862348804298511, 5.859852650392077, 5.857360996456142, 5.854873832787824, 5.85239115074355, 5.849912942056599, 5.84743919860044, 5.844969912306627, 5.842505075136324, 5.840044679070392, 5.837588716105966, 5.835137178255218, 5.832690057544945, 5.830247346016371, 5.82780903572509, 5.825375118741021, 5.822945587148377, 5.820520433045623, 5.818099648545486, 5.81568322577487, 5.813271156874896, 5.810863434000823, 5.80846004932206, 5.806060995022115, 5.803666263298584, 5.801275846363113, 5.798889736441399, 5.796507925773136, 5.794130406611994, 5.791757171225603, 5.789388211895537, 5.787023520917265, 5.78466309060014, 5.782306913267375, 5.779954981256006, 5.777607286916901, 5.7752638226146695, 5.772924580727715, 5.770589553648158, 5.768258733781823, 5.765932113548229, 5.763609685380541, 5.761291441725568, 5.758977375043727, 5.756667477809009, 5.7543617425089755, 5.752060161644726, 5.749762727730862, 5.747469433295479, 5.745180270880133, 5.742895233039813, 5.7406143123429345, 5.738337501371297, 5.736064792720062, 5.733796178997735, 5.731531652826147, 5.729271206840409, 5.727014833688914, 5.724762526033297, 5.7225142765484085, 5.720270077922318, 5.718029922856239, 5.715793804064561, 5.713561714274784, 5.711333646227526, 5.709109592676477, 5.706889546388382, 5.704673500143023, 5.7024614467331824, 5.700253378964642, 5.698049289656142, 5.695849171639346, 5.69365301775886, 5.691460820872158, 5.689272573849602, 5.687088269574389, 5.684907900942543, 5.6827314608628825, 5.680558942257016, 5.678390338059282, 5.676225641216777, 5.674064844689287, 5.671907941449298, 5.669754924481939, 5.667605786784988, 5.665460521368849, 5.663319121256497, 5.661181579483505, 5.659047889097972, 5.656918043160531, 5.65479203474433, 5.652669856934972, 5.6505515028305435, 5.648436965541551, 5.6463262381909205, 5.644219313913968, 5.64211618585838, 5.6400168471841825, 5.637921291063735, 5.635829510681697, 5.633741499235001, 5.631657249932843, 5.629576755996649, 5.6275000106600706, 5.625427007168938, 5.623357738781259, 5.62129219876718, 5.619230380408988, 5.6171722770010515, 5.615117881849848, 5.613067188273893, 5.611020189603755, 5.60897687918201, 5.606937250363236, 5.604901296513977, 5.60286901101274, 5.600840387249953, 5.59881541862795, 5.596794098560973, 5.594776420475102, 5.59276237780828, 5.590751964010269, 5.588745172542638, 5.58674199687873, 5.584742430503641, 5.582746466914222, 5.580754099619038, 5.5787653221383335, 5.5767801280040485, 5.574798510759765, 5.572820463960699, 5.57084598117369, 5.568875055977152, 5.56690768196108, 5.564943852727015, 5.562983561888031, 5.561026803068705, 5.559073569905097, 5.557123856044743, 5.555177655146618, 5.553234960881132, 5.5512957669300835, 5.549360066986667, 5.5474278547554325, 5.545499123952293, 5.543573868304452, 5.54165208155044, 5.539733757440058, 5.537818889734378, 5.5359074722057, 5.533999498637554, 5.532094962824672, 5.530193858572962, 5.528296179699488, 5.526401920032471, 5.52451107341123, 5.522623633686205, 5.520739594718902, 5.518858950381891, 5.516981694558783, 5.515107821144213, 5.5132373240438115, 5.511370197174188, 5.509506434462923, 5.507646029848531, 5.50578897728044, 5.503935270718999, 5.502084904135421, 5.500237871511788, 5.498394166841033, 5.496553784126902, 5.494716717383949, 5.492882960637509, 5.491052507923689, 5.489225353289339, 5.487401490792022, 5.4855809145000345, 5.4837636184923415, 5.481949596858575, 5.480138843699031, 5.478331353124622, 5.476527119256872, 5.47472613622791, 5.4729283981804215, 5.471133899267652, 5.469342633653388, 5.467554595511924, 5.465769779028046, 5.463988178397031, 5.46220 ...
#
# *** The final value of theta_0 is  -1.363041945790741  and theta_1 is  0.9385925462583735  ***

# %%
ynew=x_train*theta_array[1]+theta_array[0]
plt.plot(x_train,ynew,'r')
plt.scatter(x_train,y_train)

# %%
#no need to deal with the testing phase
def testing(x_test, y_test, theta_array) :
    '''function where testing is done and the mean squared error is found'''
    m = x_test.size

    SSTO = []   # total sum of squares
    SSR = []    # regression sum of squares
    SSE = []    # error sum of squares
    y_mean = np.mean(y_train)

    for i in range(m):
        prediction = hypothesis(theta_array, x_test[i])  # value of prediction (value of hypothesis at point i)
        y_i = y_test[i]                             # value of 'y' at point i
        SSE.append((prediction - y_i)**2)           # sum of values in the array is SSE (error sum of squares)
        SSR.append((prediction - y_mean)**2)        # sum of values in the array is SSR (regression sum of squares)
        SSTO.append((y_i - y_mean)**2)              # sum of values in the array is SSTO (total sum of squares)

    print('\naverage error is : ', sum(SSE)/len(SSE))
    print('\nsum of squares of error (SSE) : ', sum(SSE))
    print('\nregression sum of squares (SSR) : ', sum(SSR))
    print('\ntotal sum of squares (SSTO) : ', sum(SSTO))
    print('\nThe Coefficient Of Determination R-squared is : ', (sum(SSR)/sum(SSTO))*100,'%')

# %%
#no need to deal with this
testdata=pd.read_csv("NG Machine Learning/test.csv")
print(testdata)
testdata.shape

cleaned_testing_data = testdata.dropna()  # Cleaning the data by removing the rows with "NaN" values in them. dropna() does the job
x_test1 = cleaned_training_data.as_matrix(columns=['x'])
y_test1 = cleaned_training_data.as_matrix(columns=['y'])

# reshaping the data from (699,1) to (699)
x_test1 = x_test1.reshape(x_test1.size)
y_test1 = y_test1.reshape(y_test1.size)
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   import sys

# %%
SSTO = []   # total sum of squares
SSR = []    # regression sum of squares
SSE = []    # error sum of squares
y_mean = np.mean(y_train)

# %%
m=x_train.size
for i in range(m):
  prediction = hypothesis(theta_array, x_train[i])  # value of prediction (value of hypothesis at point i)
  y_i = y_train[i]                             # value of 'y' at point i
  SSE.append((prediction - y_i)**2)           # sum of values in the array is SSE (error sum of squares)
  SSR.append((prediction - y_mean)**2)        # sum of values in the array is SSR (regression sum of squares)
  SSTO.append((y_i - y_mean)**2)              # sum of values in the array is SSTO (total sum of squares)

# %%
print('\naverage error is : ', sum(SSE)/len(SSE))
print('\nsum of squares of error (SSE) : ', sum(SSE))
print('\nregression sum of squares (SSR) : ', sum(SSR))
print('\ntotal sum of squares (SSTO) : ', sum(SSTO))
print('\nThe Coefficient Of Determination R-squared is : ', (sum(SSR)/sum(SSTO))*100,'%')       #regression coefficient
# Out:
# average error is :  10.121935935195516
#
# sum of squares of error (SSE) :  981.827785713965
#
# regression sum of squares (SSR) :  1286.7652634237543
#
# total sum of squares (SSTO) :  2914.8470516572247
#
# The Coefficient Of Determination R-squared is :  44.145206956645254 %
